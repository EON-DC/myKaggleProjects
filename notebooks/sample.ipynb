# %% [markdown]
# # 경로 설정
# # 함수 설정

# %%
# open csv
import csv

# define file path
path_gender_submission = 'C:/Workspace/04_Study/01_AI/02_Kaggle/01_SamplesForKaggle/data/raw/kaggle/titanic/titanic/gender_submission.csv'
path_test = 'C:/Workspace/04_Study/01_AI/02_Kaggle/01_SamplesForKaggle/data/raw/kaggle/titanic/titanic/test.csv'
path_train = 'C:/Workspace/04_Study/01_AI/02_Kaggle/01_SamplesForKaggle/data/raw/kaggle/titanic/titanic/train.csv'

# define method to read csv file
def read_csv(path):
    with open(path, mode='r') as file:
        # read csv
        csvFile = csv.reader(file)
        # display csv content
        for lines in csvFile:
            print(lines)

# %% [markdown]
# ## 데이터 확인

# %%
100/7
# Out:
# 14.285714285714286
